# %%
import pandas as pd
import mlflow
import dagshub
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from mlflow.pyfunc import PythonModel
import numpy as np
import litellm
from mlflow.genai import scorer
from mlflow.genai.scorers import Correctness, Guidelines
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GOOGLE_API_KEY"]
# Out:
# 'AIzaSyDTeTM4TmhEKgUqECw1c_IsUPAkxKwD3Uc'

# %%
dagshub.init(repo_owner='paruldiwakar',
             repo_name='mlflow-genai',
             mlflow=True)


mlflow.set_tracking_uri("https://dagshub.com/paruldiwakar/mlflow-genai.mlflow")
# Out:
# Accessing as paruldiwakar
# Initialized MLflow to track repo "paruldiwakar/mlflow-genai"
# Repository paruldiwakar/mlflow-genai initialized!

# %% [markdown]
# ### Define your mock agent's prediction function

# %%
llm = ChatGroq(
    model="moonshotai/kimi-k2-instruct-0905",
    temperature=0.1,
)

# %%
from langchain.schema import SystemMessage, HumanMessage

def my_agent(question: str) -> str:
    response = llm.invoke([
        SystemMessage(
            content="You are a helpful assistant. Answer the following question in one sentences."
        ),
        HumanMessage(content=question),
    ])
    return response.content

# Wrapper function for evaluation
def qa_predict_fn(question: str) -> str:
    return my_agent(question)

# %%
type(qa_predict_fn("wazzaup"))
# Out:
# str

# %% [markdown]
# ### Prepare an evaluation dataset

# %% [markdown]
# ### Define evaluation criteria using Scorers

# %%
@scorer
def is_concise(outputs: str) -> bool:
    """Evaluate if the answer is concise (less than 5 words)"""
    return len(outputs.split()) <= 20

# %%
from mlflow.genai.scorers import Correctness

assessment = Correctness(
    name="my_correctness",
    model="gemini:/gemini-2.5-flash"
)(
    inputs={
        "question": "What is the difference between reduceByKey and groupByKey in Spark?"
    },
    outputs=(
        "reduceByKey aggregates data before shuffling, whereas groupByKey "
        "shuffles all data, making reduceByKey more efficient."
    ),
    expectations={
        "expected_facts": [
            "reduceByKey aggregates data before shuffling",
            "groupByKey shuffles all data"
        ]
    },
)

print(assessment)
# Out:
# Feedback(name='my_correctness', source=AssessmentSource(source_type='LLM_JUDGE', source_id='gemini:/gemini-2.5-flash'), trace_id=None, run_id=None, rationale='The response is correct. The document states "reduceByKey aggregates data before shuffling" which supports the first part of the claim. The document also states "groupByKey shuffles all data" which supports the second part of the claim.', metadata={'mlflow.assessment.judgeCost': 0.0006940000000000001}, span_id=None, create_time_ms=1767169975404, last_update_time_ms=1767169975404, assessment_id=None, error=None, expectation=None, feedback=FeedbackValue(value=<CategoricalRating.YES: 'yes'>, error=None), overrides=None, valid=True)

# %%
print(assessment.rationale)
# Out:
# The claim states "reduceByKey aggregates data before shuffling" and the document states "reduceByKey aggregates data before shuffling". The claim also states "groupByKey shuffles all data" and the document states "groupByKey shuffles all data". Both parts of the claim are directly supported by the document in the context of the question. The response is correct

# %%
import mlflow
from mlflow.genai.scorers import Correctness

# Fix tracking
mlflow.set_tracking_uri("file:./mlruns")
mlflow.set_experiment("test")

# Two samples
data = [
    {
        "inputs": {"question": "What is Spark?"},
        "outputs": "Spark is a distributed data processing framework.",
        "expectations": {"expected_response": "Spark is a distributed data processing engine."}
    },
    {
        "inputs": {"question": "What is reduceByKey?"},
        "outputs": "reduceByKey aggregates data before shuffling.",
        "expectations": {"expected_response": "reduceByKey combines values before shuffle."}
    }
]

# Evaluate with Gemini
result = mlflow.genai.evaluate(
    data=data,
    scorers=[
        Correctness(model="gemini:/gemini-2.5-flash"),
        Guidelines(name="is_english", guidelines="The answer must be in English",model="gemini:/gemini-2.5-flash"),
        is_concise,
        
        ]
)

print(result.metrics)
# Out:
# Evaluating: 100%|██████████| 2/2 [Elapsed: 00:03, Remaining: 00:00]
# ✨ Evaluation completed.
#
# Metrics and evaluation results are logged to the MLflow run:
#   Run name: angry-goose-933
#   Run ID: 6ae16ad0084a47eb9e2f542e277b399c
#
# To view the detailed evaluation results with sample-wise scores,
# open the Traces tab in the Run page in the MLflow UI.
#
# {'is_concise/mean': 0.5, 'is_english/mean': 1.0, 'correctness/mean': 0.5}

# %%
result.tables['eval_results']
# Out:
#                               trace_id  \
# 0  tr-b3df5f9a9f9b4c8a99f31aa7b667df13
# 1  tr-e130d31281fdff1328531a699ab0deef
#
#                           expected_response/value is_english/value  \
# 0  Spark is a distributed data processing engine.              yes
# 1     reduceByKey combines values before shuffle.              yes
#
#    is_concise/value correctness/value  \
# 0             False                no
# 1              True               yes
#
#                                                trace client_request_id state  \
# 0  {"info": {"trace_id": "tr-b3df5f9a9f9b4c8a99f3...              None    OK
# 1  {"info": {"trace_id": "tr-e130d31281fdff132853...              None    OK
#
#     request_time  execution_duration                               request  \
# 0  1767170727653                   0        {'question': 'What is Spark?'}
# 1  1767170727655                   0  {'question': 'What is reduceByKey?'}
#
#                                             response  \
# 0  Spark is a distributed data processing framework.
# 1      reduceByKey aggregates data before shuffling.
#
#                                       trace_metadata  \
# 0  {'mlflow.trace_schema.version': '3', 'mlflow.u...
# 1  {'mlflow.trace_schema.version': '3', 'mlflow.u...
#
#                                                 tags  \
# 0  {'mlflow.eval.requestId': '4ed20b0e698c4cbd703...
# 1  {'mlflow.eval.requestId': 'c89e669e79a19ec4e16...
#
#                                                spans  \
# 0  [{'trace_id': 's99fmp+bTIqZ8xqntmffEw==', 'spa...
# 1  [{'trace_id': '4TDTEoH9/xMoUxppmrDe7w==', 'spa...
#
#                                          assessments
# 0  [{'assessment_id': 'a-a51b0f5b6e2c495d87c709be...
# 1  [{'assessment_id': 'a-523ece5df90f4358a01785ff...

# %% [markdown]
# ## Now on mlflow and storing it on Dagshub

# %%
# Prepare evaluation data
eval_data = [
    {
        "inputs": {
            "question": "What is MLflow?"
        },
        "expectations": {
            "expected_response": (
                "MLflow is an open-source platform for managing the end-to-end machine learning lifecycle."
            )
        }
    },
    {
        "inputs": {
            "question": "What is Spark?"
        },
        "expectations": {
            "expected_response": (
                "Apache Spark is an open-source, distributed computing system designed for big data processing and analytics."
            )
        }
    }
]


# Set experiment
mlflow.set_experiment("LLM Evaluation - Kimi with Gemini Judge")

# Run evaluation
with mlflow.start_run(run_name="kimi-qa-evaluation") as run:
    print(f"Run ID: {run.info.run_id}")
    print("Starting evaluation...\n")
    
    # Evaluate with Gemini as judge
    results = mlflow.genai.evaluate(
        data=eval_data,
        predict_fn=qa_predict_fn,
        scorers=[
            Correctness(model="gemini:/gemini-2.5-flash"),
            Guidelines(
                name="is_english", 
                guidelines="The answer must be in English",
                model="gemini:/gemini-2.5-flash"
            ),
            is_concise
        ]
    )
    
    print("\n" + "="*60)
    print("AGGREGATED EVALUATION RESULTS")
    print("="*60)
    for metric, value in results.metrics.items():
        print(f"{metric}: {value}")
    
    # Save evaluation results to CSV
    eval_table = result.tables['eval_results']
    df = pd.DataFrame(eval_table)
    df.to_csv('eval_kimi_gemini.csv', index=False)
    
    print("\n" + "="*60)
    print("EVALUATION TABLE")
    print("="*60)
    print(df.to_string())
    print(f"\n✅ Evaluation results saved to 'eval_kimi_gemini.csv'")
    print(f"✅ View full results in MLflow UI: {mlflow.get_tracking_uri()}")
# Out:
# 2025/12/31 14:47:46 INFO mlflow.genai.utils.data_validation: Testing model prediction with the first sample in the dataset. To disable this check, set the MLFLOW_GENAI_EVAL_SKIP_TRACE_VALIDATION environment variable to True.
# 2025/12/31 14:47:46 WARNING mlflow.tracing.fluent: Failed to start span ChatGroq: 'NonRecordingSpan' object has no attribute 'context'. For full traceback, set logging level to debug.
# Run ID: 1944a87d352d4778ae9293a97d7a586f
# Starting evaluation...
# Evaluating: 100%|██████████| 2/2 [Elapsed: 00:08, Remaining: 00:00]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Evaluation output</title>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#
#         .header {
#             a.button {
#                 padding: 4px 8px;
#                 line-height: 20px;
#                 box-shadow: none;
#                 height: 20px;
#                 display: inline-flex;
#                 align-items: center;
#                 justify-content: center;
#                 vertical-align: middle;
#                 background-color: rgb(34, 114, 180);
#                 color: rgb(255, 255, 255);
#                 text-decoration: none;
#                 animation-duration: 0s;
#                 transition: none 0s ease 0s;
#                 position: relative;
#                 white-space: nowrap;
#                 text-align: center;
#                 border: 1px solid rgb(192, 205, 216);
#                 cursor: pointer;
#                 user-select: none;
#                 touch-action: manipulation;
#                 border-radius: 4px;
#                 gap: 6px;
#             }
#
#             a.button:hover {
#                 background-color: rgb(14, 83, 139) !important;
#                 border-color: transparent !important;
#                 color: rgb(255, 255, 255) !important;
#             }
#         }
#
#         .warnings-section {
#             margin-top: 8px;
#
#             ul {
#                 list-style-type: none;
#             }
#         }
#
#         .instructions-section {
#             margin-top: 16px;
#             font-size: 14px;
#
#             ul {
#                 margin-top: 0;
#                 margin-bottom: 0;
#             }
#         }
#
#         code {
#             font-family: monospace;
#         }
#
#         .note {
#             color: #666;
#         }
#
#         a {
#             color: #2272B4;
#             text-decoration: none;
#         }
#
#         a:hover {
#             color: #005580;
#         }
#     </style>
# </head>
# <body>
# <div>
#     <div class="header">
#         <a href="https://dagshub.com/paruldiwakar/mlflow-genai.mlflow/#/experiments/3/evaluation-runs?selectedRunUuid=1944a87d352d4778ae9293a97d7a586f" class="button">
#             View evaluation results in MLflow
#             <svg xmlns="http://www.w3.org/2000/svg" width="1em" height="1em" fill="none" viewBox="0 0 16 16" aria-hidden="true" focusable="false" class="">
#                 <path fill="currentColor" d="M10 1h5v5h-1.5V3.56L8.53 8.53 7.47 7.47l4.97-4.97H10z"></path>
#                 <path fill="currentColor" d="M1 2.75A.75.75 0 0 1 1.75 2H8v1.5H2.5v10h10V8H14v6.25a.75.75 0 0 1-.75.75H1.75a.75.75 0 0 1-.75-.75z"></path>
#             </svg>
#         </a>
#     </div>
# </div>
# </body>
# </html>
# ============================================================
# AGGREGATED EVALUATION RESULTS
# ============================================================
# is_concise/mean: 1.0
# is_english/mean: 1.0
# correctness/mean: 1.0
#
# ============================================================
# EVALUATION TABLE
# ============================================================
#                               trace_id                         expected_response/value is_english/value  is_concise/value correctness/value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 0  tr-b3df5f9a9f9b4c8a99f31aa7b667df13  Spark is a distributed data processing engine.              yes             False                no  {"info": {"trace_id": "tr-b3df5f9a9f9b4c8a99f31aa7b667df13", "trace_location": {"type": "MLFLOW_EXPERIMENT", "mlflow_experiment": {"experiment_id": "520335319363625619"}}, "request_time": "2025-12-31T08:45:27.653Z", "state": "OK", "trace_metadata": {"mlflow.sourceRun": "6ae16ad0084a47eb9e2f542e277b399c", "mlflow.trace_schema.version": "3", "mlflow.traceInputs": "{\"question\": \"What is Spark?\"}", "mlflow.trace.sizeStats": "{\"total_size_bytes\": 1658, \"num_spans\": 1, \"max\": 521, \"p25\": 521, \"p50\": 521, \"p75\": 521}", "mlflow.source.type": "LOCAL", "mlflow.source.git.branch": "main", "mlflow.source.name": "/Users/paruldiwakar/Desktop/mlflow-genai/venv/lib/python3.11/site-packages/ipykernel_launcher.py", "mlflow.source.git.commit": "", "mlflow.user": "paruldiwakar", "mlflow.source.git.repoURL": "https://github.com/paruldiwakar/mlflow-genai.git", "mlflow.traceOutputs": "\"Spark is a distributed data processing framework.\"", "mlflow.trace.sizeBytes": "1658"}, "assessments": [{"assessment_id": "a-a51b0f5b6e2c495d87c709be8b153bf2", "assessment_name": "expected_response", "trace_id": "tr-b3df5f9a9f9b4c8a99f31aa7b667df13", "span_id": "53dbf7e6032ea951", "source": {"source_type": "HUMAN", "source_id": "paruldiwakar"}, "create_time": "2025-12-31T08:45:30.713Z", "last_update_time": "2025-12-31T08:45:30.713Z", "expectation": {"value": "Spark is a distributed data processing engine."}, "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c"}}, {"assessment_id": "a-be2f99bfad5942d78ca2ecfa9e92ce7f", "assessment_name": "is_english", "trace_id": "tr-b3df5f9a9f9b4c8a99f31aa7b667df13", "span_id": "53dbf7e6032ea951", "source": {"source_type": "LLM_JUDGE", "source_id": "gemini:/gemini-2.5-flash"}, "create_time": "2025-12-31T08:45:30.711Z", "last_update_time": "2025-12-31T08:45:30.711Z", "feedback": {"value": "yes"}, "rationale": "The guideline states that \"The answer must be in English\". The provided response \"Spark is a distributed data processing framework.\" is entirely in English. Therefore, the response fully complies with the given guideline.", "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c", "mlflow.assessment.judgeCost": "0.0005095"}, "valid": true}, {"assessment_id": "a-531905291eb94a36a16b6861b81cde29", "assessment_name": "is_concise", "trace_id": "tr-b3df5f9a9f9b4c8a99f31aa7b667df13", "span_id": "53dbf7e6032ea951", "source": {"source_type": "CODE", "source_id": "is_concise"}, "create_time": "2025-12-31T08:45:30.709Z", "last_update_time": "2025-12-31T08:45:30.709Z", "feedback": {"value": false}, "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c"}, "valid": true}, {"assessment_id": "a-012c47d8b431494382639ffd183a3262", "assessment_name": "correctness", "trace_id": "tr-b3df5f9a9f9b4c8a99f31aa7b667df13", "span_id": "53dbf7e6032ea951", "source": {"source_type": "LLM_JUDGE", "source_id": "gemini:/gemini-2.5-flash"}, "create_time": "2025-12-31T08:45:30.712Z", "last_update_time": "2025-12-31T08:45:30.712Z", "feedback": {"value": "no"}, "rationale": "The claim states that Spark is a \"distributed data processing engine\". The document states that Spark is a \"distributed data processing framework\". While 'engine' and 'framework' are related concepts in software, they are not exact synonyms. The document does not explicitly state that Spark is an 'engine'. Therefore, the claim is not fully supported by the document.", "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c", "mlflow.assessment.judgeCost": "0.0009399000000000001"}, "valid": true}], "tags": {"mlflow.artifactLocation": "file:///Users/paruldiwakar/Desktop/mlflow-genai/mlruns/520335319363625619/traces/tr-b3df5f9a9f9b4c8a99f31aa7b667df13/artifacts", "mlflow.eval.requestId": "4ed20b0e698c4cbd7033736a59684888ea7c8ec5f45bf8 ...
# 1  tr-e130d31281fdff1328531a699ab0deef     reduceByKey combines values before shuffle.              yes              True               yes        {"info": {"trace_id": "tr-e130d31281fdff1328531a699ab0deef", "trace_location": {"type": "MLFLOW_EXPERIMENT", "mlflow_experiment": {"experiment_id": "520335319363625619"}}, "request_time": "2025-12-31T08:45:27.655Z", "state": "OK", "trace_metadata": {"mlflow.sourceRun": "6ae16ad0084a47eb9e2f542e277b399c", "mlflow.trace_schema.version": "3", "mlflow.traceInputs": "{\"question\": \"What is reduceByKey?\"}", "mlflow.trace.sizeStats": "{\"total_size_bytes\": 1664, \"num_spans\": 1, \"max\": 523, \"p25\": 523, \"p50\": 523, \"p75\": 523}", "mlflow.source.type": "LOCAL", "mlflow.source.git.branch": "main", "mlflow.source.name": "/Users/paruldiwakar/Desktop/mlflow-genai/venv/lib/python3.11/site-packages/ipykernel_launcher.py", "mlflow.source.git.commit": "", "mlflow.user": "paruldiwakar", "mlflow.source.git.repoURL": "https://github.com/paruldiwakar/mlflow-genai.git", "mlflow.traceOutputs": "\"reduceByKey aggregates data before shuffling.\"", "mlflow.trace.sizeBytes": "1664"}, "assessments": [{"assessment_id": "a-523ece5df90f4358a01785ff49f31b7b", "assessment_name": "correctness", "trace_id": "tr-e130d31281fdff1328531a699ab0deef", "span_id": "b054ad1d94068716", "source": {"source_type": "LLM_JUDGE", "source_id": "gemini:/gemini-2.5-flash"}, "create_time": "2025-12-31T08:45:30.593Z", "last_update_time": "2025-12-31T08:45:30.593Z", "feedback": {"value": "yes"}, "rationale": "The claim states that \"reduceByKey combines values before shuffle.\" The document states that \"reduceByKey aggregates data before shuffling.\" The terms \"combines values\" and \"aggregates data\" are synonymous in the context of reduceByKey's function. The phrase \"before shuffle\" is also directly supported by \"before shuffling\" in the document. Therefore, the claim is fully supported by the document.", "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c", "mlflow.assessment.judgeCost": "0.0007274"}, "valid": true}, {"assessment_id": "a-fc83c1369c5e48fcbfbddc973fa6e875", "assessment_name": "is_english", "trace_id": "tr-e130d31281fdff1328531a699ab0deef", "span_id": "b054ad1d94068716", "source": {"source_type": "LLM_JUDGE", "source_id": "gemini:/gemini-2.5-flash"}, "create_time": "2025-12-31T08:45:30.592Z", "last_update_time": "2025-12-31T08:45:30.592Z", "feedback": {"value": "yes"}, "rationale": "The guideline states \"The answer must be in English\". The provided response \"reduceByKey aggregates data before shuffling.\" is entirely in English. Therefore, the guideline is satisfied.", "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c", "mlflow.assessment.judgeCost": "0.0004195"}, "valid": true}, {"assessment_id": "a-6d7c367363154882b070bafc801d9932", "assessment_name": "is_concise", "trace_id": "tr-e130d31281fdff1328531a699ab0deef", "span_id": "b054ad1d94068716", "source": {"source_type": "CODE", "source_id": "is_concise"}, "create_time": "2025-12-31T08:45:30.589Z", "last_update_time": "2025-12-31T08:45:30.589Z", "feedback": {"value": true}, "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c"}, "valid": true}, {"assessment_id": "a-8456bfa057b7415da4a0e484ba5a5c0f", "assessment_name": "expected_response", "trace_id": "tr-e130d31281fdff1328531a699ab0deef", "span_id": "b054ad1d94068716", "source": {"source_type": "HUMAN", "source_id": "paruldiwakar"}, "create_time": "2025-12-31T08:45:30.595Z", "last_update_time": "2025-12-31T08:45:30.595Z", "expectation": {"value": "reduceByKey combines values before shuffle."}, "metadata": {"mlflow.assessment.sourceRunId": "6ae16ad0084a47eb9e2f542e277b399c"}}], "tags": {"mlflow.artifactLocation": "file:///Users/paruldiwakar/Desktop/mlflow-genai/mlruns/520335319363625619/traces/tr-e130d31281fdff1328531a699ab0deef/artifacts", "mlflow.eval.requestId": "c89e669e79a19ec4e1684b77c7a89d772aa74d286c5eea2c4e ...
#
# ✅ Evaluation results saved to 'eval_kimi_gemini.csv'
# ✅ View full results in MLflow UI: https://dagshub.com/paruldiwakar/mlflow-genai.mlflow
